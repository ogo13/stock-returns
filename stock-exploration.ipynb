# %%
# linear algebra
import numpy as np 

# data processing, CSV file I/O (e.g. pd.read_csv)
import pandas as pd 

# data visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# stocks related missing info
import yfinance as yf

# %%
df = pd.read_csv('data/sp500_companies.csv')
df.head(5)
# Out:
#   Exchange Symbol              Shortname               Longname  \
# 0      NMS   AAPL             Apple Inc.             Apple Inc.
# 1      NMS   NVDA     NVIDIA Corporation     NVIDIA Corporation
# 2      NMS   MSFT  Microsoft Corporation  Microsoft Corporation
# 3      NMS   AMZN       Amazon.com, Inc.       Amazon.com, Inc.
# 4      NMS  GOOGL          Alphabet Inc.          Alphabet Inc.
#
#                    Sector                        Industry  Currentprice  \
# 0              Technology            Consumer Electronics        254.49
# 1              Technology                  Semiconductors        134.70
# 2              Technology       Software - Infrastructure        436.60
# 3       Consumer Cyclical                 Internet Retail        224.92
# 4  Communication Services  Internet Content & Information        191.41
#
#        Marketcap        Ebitda  Revenuegrowth           City State  \
# 0  3846819807232  1.346610e+11          0.061      Cupertino    CA
# ...

# %%
# https://www.kaggle.com/code/faryarmemon/s-p-500-stock-analysis-for-beginners

# %%
df.describe()
# Out:
#        Currentprice     Marketcap        Ebitda  Revenuegrowth  \
# count    502.000000  5.020000e+02  4.730000e+02     499.000000
# mean     217.893685  1.107222e+11  7.045286e+09       0.070541
# std      489.205027  3.440074e+11  1.624213e+10       0.180247
# min        9.400000  4.664099e+09 -3.991000e+09      -0.602000
# 25%       68.547500  1.933417e+10  1.625000e+09       0.002000
# 50%      118.365000  3.706396e+10  2.952748e+09       0.051000
# 75%      227.667500  7.830565e+10  6.020000e+09       0.109000
# max     8276.780000  3.846820e+12  1.495470e+11       1.632000
#
#        Fulltimeemployees      Weight
# count       4.930000e+02  502.000000
# mean        5.782761e+04    0.001992
# std         1.395988e+05    0.006189
# min         2.800000e+01    0.000084
# 25%         1.020000e+04    0.000348
# 50%         2.169000e+04    0.000667
# 75%         5.510000e+04    0.001409
# max         2.100000e+06    0.069209

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 502 entries, 0 to 501
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Exchange             502 non-null    object
#  1   Symbol               502 non-null    object
#  2   Shortname            502 non-null    object
#  3   Longname             502 non-null    object
#  4   Sector               502 non-null    object
#  5   Industry             502 non-null    object
#  6   Currentprice         502 non-null    float64
#  7   Marketcap            502 non-null    int64
#  8   Ebitda               473 non-null    float64
#  9   Revenuegrowth        499 non-null    float64
#  10  City                 502 non-null    object
#  11  State                482 non-null    object
#  12  Country              502 non-null    object
#  13  Fulltimeemployees    493 non-null    float64
#  14  Longbusinesssummary  502 non-null    object
# ...

# %%
df[np.isnan(df['Ebitda'])].head()
# Out:
#    Exchange Symbol                    Shortname                     Longname  \
# 12      NYQ    JPM        JP Morgan Chase & Co.         JPMorgan Chase & Co.
# 23      NYQ    BAC  Bank of America Corporation  Bank of America Corporation
# 30      NYQ    WFC        Wells Fargo & Company        Wells Fargo & Company
# 34      NYQ    AXP     American Express Company     American Express Company
# 37      NYQ     BX              Blackstone Inc.              Blackstone Inc.
#
#                 Sector             Industry  Currentprice     Marketcap  \
# 12  Financial Services  Banks - Diversified        237.60  668924837888
# 23  Financial Services  Banks - Diversified         44.17  338911100928
# 30  Financial Services  Banks - Diversified         70.34  234196303872
# 34  Financial Services      Credit Services        298.65  210382487552
# 37  Financial Services     Asset Management        170.84  207208415232
#
#     Ebitda  Revenuegrowth           City State        Country  \
# ...

# %%
df[np.isnan(df['Revenuegrowth'])].head()
# Out:
#     Exchange Symbol                        Shortname  \
# 55       NYQ     VZ      Verizon Communications Inc.
# 109      NYQ    AMT  American Tower Corporation (REI
# 359      NMS    WDC      Western Digital Corporation
#
#                         Longname                  Sector           Industry  \
# 55   Verizon Communications Inc.  Communication Services   Telecom Services
# 109   American Tower Corporation             Real Estate   REIT - Specialty
# 359  Western Digital Corporation              Technology  Computer Hardware
#
#      Currentprice     Marketcap        Ebitda  Revenuegrowth      City State  \
# 55          39.93  168090517504  4.842900e+10            NaN  New York    NY
# 109        183.73   85855002624  6.966100e+09            NaN    Boston    MA
# 359         60.24   20825450496  2.134000e+09            NaN  San Jose    CA
#
#            Country  Fulltimeemployees  \
# 55   United States           101200.0
# 109  United States             5643.0
# ...

# %%
df.loc[df['Symbol']=="VZ", "Revenuegrowth"] = yf.Ticker("VZ").info["revenueGrowth"]

# %%
df.dropna(subset=['Revenuegrowth'], inplace=True)
df[np.isnan(df['Revenuegrowth'])].head()
# Out:
# Empty DataFrame
# Columns: [Exchange, Symbol, Shortname, Longname, Sector, Industry, Currentprice, Marketcap, Ebitda, Revenuegrowth, City, State, Country, Fulltimeemployees, Longbusinesssummary, Weight]
# Index: []

# %%
df[(df['State']).isna()].head()
# Out:
#    Exchange Symbol               Shortname               Longname  \
# 32      NYQ    ACN           Accenture plc          Accenture plc
# 40      NMS    LIN               Linde plc              Linde plc
# 75      NYQ    ETN  Eaton Corporation, PLC  Eaton Corporation plc
# 90      NYQ     CB           Chubb Limited          Chubb Limited
# 94      NYQ    MDT          Medtronic plc.          Medtronic plc
#
#                 Sector                         Industry  Currentprice  \
# 32          Technology  Information Technology Services        366.37
# 40     Basic Materials              Specialty Chemicals        424.31
# 75         Industrials   Specialty Industrial Machinery        338.12
# 90  Financial Services  Insurance - Property & Casualty        273.20
# 94          Healthcare                  Medical Devices         81.03
#
#        Marketcap        Ebitda  Revenuegrowth    City State         Country  \
# ...

# %%
df = df.drop(['State'], axis=1) # drop State column since it is not really relevent

# %%
df[np.isnan(df['Fulltimeemployees'])].head()
# Out:
#     Exchange Symbol                      Shortname  \
# 13       NYQ      V                      Visa Inc.
# 97       NMS   SBUX          Starbucks Corporation
# 206      NYQ    DHI              D.R. Horton, Inc.
# 257      NYQ    RMD                    ResMed Inc.
# 274      NYQ    RJF  Raymond James Financial, Inc.
#
#                           Longname              Sector  \
# 13                       Visa Inc.  Financial Services
# 97           Starbucks Corporation   Consumer Cyclical
# 206              D.R. Horton, Inc.   Consumer Cyclical
# 257                    ResMed Inc.          Healthcare
# 274  Raymond James Financial, Inc.  Financial Services
#
#                            Industry  Currentprice     Marketcap        Ebitda  \
# 13                  Credit Services        317.71  615235846144  2.497300e+10
# 97                      Restaurants         87.97   99740385280  6.700000e+09
# 206        Residential Construction        139.61   44790935552  6.202900e+09
# ...

# %%
df.loc[df['Fulltimeemployees'].isnull(), 'Fulltimeemployees'] = df['Fulltimeemployees'].mode()[0]

# %%
# Out:
# 10
